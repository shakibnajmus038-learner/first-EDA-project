# %% [markdown]
# **We'll use the NETFLIX Movies and TV Shows dataset**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# Read all files

for file in os.listdir('./Data.Netflix'):
    print(file)
# Out:
# all_file.csv
# file1.csv
# file2.csv
# file3.csv
# file4.csv
# file5.csv
# .ipynb_checkpoints

# %%
# Merge all files into one

all_file=pd.DataFrame()

for file in os.listdir('./Data.Netflix'):
    if file.endswith('.csv'):
        df=pd.read_csv('./Data.Netflix/'+file)
        all_file=pd.concat([all_file,df])

all_file.shape
# Out:
# (21641, 12)

# %%
# Check Duplicates Rows

all_file[all_file.duplicated()]
# Out:
#          show_id                                title  \
# 0     81193313.0                            Chocolate
# 1     81197050.0  Guatemala: Heart of the Mayan World
# 2     81213894.0                      The Zoya Factor
# 3     81082007.0                            Atlantics
# 4     80213643.0                      Chip and Potato
# ...          ...                                  ...
# 1441  70141644.0          Mad Ron's Prevues from Hell
# 1442  70127998.0                             Splatter
# 1443  70084180.0              Just Another Love Story
# 1444  70157452.0                      Dinner for Five
# 1445  70053412.0                 To and From New York
#
#                         director  \
# 0                            NaN
# 1     Luis Ara, Ignacio Jaunsolo
# 2                Abhishek Sharma
# 3                      Mati Diop
# 4                            NaN
# ...                          ...
# 1441                  Jim Monaco
# 1442                   Joe Dante
# ...

# %% [markdown]
# **Is there any Duplicate Record in this dataset ? If yes, then remove the duplicate records.**

# %%
# Remove Duplicates Rows

all_file.drop_duplicates(inplace=True)
all_file.shape
# Out:
# (5838, 12)

# %%
# Create a new file and save into it

all_file.to_csv('./Data.Netflix/all_file.csv',index=False)

# %%
# read your updated DataFrame

df=pd.read_csv('./Data.Netflix/all_file.csv')
df.head(2)
# Out:
#       show_id                                title  \
# 0  81193313.0                            Chocolate
# 1  81197050.0  Guatemala: Heart of the Mayan World
#
#                      director  \
# 0                         NaN
# 1  Luis Ara, Ignacio Jaunsolo
#
#                                                 cast      country  \
# 0  Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...  South Korea
# 1                                  Christian Morales          NaN
#
#           date_added  release_year rating  duration  \
# 0  November 30, 2019        2019.0  TV-14  1 Season
# 1  November 30, 2019        2019.0   TV-G    67 min
#
#                                            listed_in  \
# 0  International TV Shows, Korean TV Shows, Roman...
# 1                Documentaries, International Movies
#
#                                          description     type
# 0  Brought together by meaningful meals in the pa...  TV Show
# ...

# %%
# Check Duplicate Values

df.duplicated().sum()
# Out:
# 0

# %%
# View Basic Infos
# Check Shape of your DataFrame How many rows and columns

df.shape
# Out:
# (5838, 12)

# %%
# Check Summary of columns and Data types

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5838 entries, 0 to 5837
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5837 non-null   float64
#  1   title         5837 non-null   object
#  2   director      3936 non-null   object
#  3   cast          5281 non-null   object
#  4   country       5410 non-null   object
#  5   date_added    5195 non-null   object
#  6   release_year  5837 non-null   float64
#  7   rating        5827 non-null   object
#  8   duration      5837 non-null   object
#  9   listed_in     5837 non-null   object
#  10  description   5837 non-null   object
#  11  type          5837 non-null   object
# dtypes: float64(2), object(10)
# memory usage: 547.4+ KB

# %% [markdown]
# **Describe Summary Statistical of Numerical columns**

# %%
df.describe()
# Out:
#             show_id  release_year
# count  5.837000e+03   5837.000000
# mean   7.730079e+07   2013.688539
# std    9.479777e+06      8.419088
# min    2.698800e+05   1925.000000
# 25%    8.004520e+07   2013.000000
# 50%    8.016353e+07   2016.000000
# 75%    8.024188e+07   2018.000000
# max    8.122720e+07   2020.000000

# %%
# (1)= Perform some operations on columns
# Get list of all columns names


df.columns
# Out:
# Index(['show_id', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'type'],
#       dtype='object')

# %%
# Convert all the columns name into List

df.columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['show_id', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'type'],
#       dtype='object')>

# %%
# Get single and multiple columns values

df['cast']
df[['cast','country']]
# Out:
#                                                    cast  \
# 0     Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...
# 1                                     Christian Morales
# 2     Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3     Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# 4     Abigail Oliver, Andrea Libman, Briana Buckmast...
# ...                                                 ...
# 5833  Nick Pawlow, Jordu Schell, Jay Kushwara, Micha...
# 5834  Corey Feldman, Tony Todd, Tara Leigh, Erin Way...
# 5835  Anders W. Berthelsen, Rebecka Hemse, Nikolaj L...
# 5836                                                NaN
# 5837  Barbara King, Shaana Diya, John Krisiukenas, Y...
#
#                        country
# 0                  South Korea
# 1                          NaN
# 2                        India
# 3     France, Senegal, Belgium
# 4       Canada, United Kingdom
# ...                        ...
# 5833             United States
# 5834             United States
# ...

# %%
# Access the columns through using iIoc and Loc

df.iloc[1::2,[4,5]].head(5)
# Out:
#                     country         date_added
# 1                       NaN  November 30, 2019
# 3  France, Senegal, Belgium  November 29, 2019
# 5                   Nigeria  November 29, 2019
# 7              South Africa  November 29, 2019
# 9                       NaN  November 29, 2019

# %%
# Access the columns through using iIoc and Loc

df.loc[1::2,['cast','country']].head()
# Out:
#                                                 cast                   country
# 1                                  Christian Morales                       NaN
# 3  Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...  France, Senegal, Belgium
# 5  Ramsey Nouah, Chigul, Sola Sobowale, Ireti Doy...                   Nigeria
# 7  Thabo Rametsi, Thabo Malema, Welile Nzuza, Jaf...              South Africa
# 9  Nonso Diobi, Mike Ezuruonye, Mercy Aigbe, Rex ...                       NaN

# %%
# Using index set the index columns wise/ Now columns is set as row index

df.set_index('show_id').head(2)
# Out:
#                                           title                    director  \
# show_id
# 81193313.0                            Chocolate                         NaN
# 81197050.0  Guatemala: Heart of the Mayan World  Luis Ara, Ignacio Jaunsolo
#
#                                                          cast      country  \
# show_id
# 81193313.0  Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...  South Korea
# 81197050.0                                  Christian Morales          NaN
#
#                    date_added  release_year rating  duration  \
# show_id
# 81193313.0  November 30, 2019        2019.0  TV-14  1 Season
# 81197050.0  November 30, 2019        2019.0   TV-G    67 min
#
#                                                     listed_in  \
# show_id
# 81193313.0  International TV Shows, Korean TV Shows, Roman...
# 81197050.0                Documentaries, International Movies
#
#                                                   description     type
# show_id
# ...

# %%
# Rename any columns

df.rename(columns={'title':'Movie Title'}).head(2)
# Out:
#       show_id                          Movie Title  \
# 0  81193313.0                            Chocolate
# 1  81197050.0  Guatemala: Heart of the Mayan World
#
#                      director  \
# 0                         NaN
# 1  Luis Ara, Ignacio Jaunsolo
#
#                                                 cast      country  \
# 0  Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...  South Korea
# 1                                  Christian Morales          NaN
#
#           date_added  release_year rating  duration  \
# 0  November 30, 2019        2019.0  TV-14  1 Season
# 1  November 30, 2019        2019.0   TV-G    67 min
#
#                                            listed_in  \
# 0  International TV Shows, Korean TV Shows, Roman...
# 1                Documentaries, International Movies
#
#                                          description     type
# 0  Brought together by meaningful meals in the pa...  TV Show
# ...

# %%
# Check and Change any dtype 

df['date_added'].dtype
# Out:
# dtype('O')

# %%
df['date_added']=pd.to_datetime(df['date_added'])
df['date_added'].dtype
# Out:
# dtype('<M8[ns]')

# %%
# Add new column of 'year'
df['year']=df['date_added'].dt.year
df.head(2)
# Out:
#       show_id                                title  \
# 0  81193313.0                            Chocolate
# 1  81197050.0  Guatemala: Heart of the Mayan World
#
#                      director  \
# 0                         NaN
# 1  Luis Ara, Ignacio Jaunsolo
#
#                                                 cast      country date_added  \
# 0  Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...  South Korea 2019-11-30
# 1                                  Christian Morales          NaN 2019-11-30
#
#    release_year rating  duration  \
# 0        2019.0  TV-14  1 Season
# 1        2019.0   TV-G    67 min
#
#                                            listed_in  \
# 0  International TV Shows, Korean TV Shows, Roman...
# 1                Documentaries, International Movies
#
#                                          description     type    year
# 0  Brought together by meaningful meals in the pa...  TV Show  2019.0
# ...

# %%
# Create new  column

df['month']=df['date_added'].dt.month
df.head(2)

# Drop any column

df.drop(columns='month',inplace=True)
df.head(2)
# Out:
#       show_id                                title  \
# 0  81193313.0                            Chocolate
# 1  81197050.0  Guatemala: Heart of the Mayan World
#
#                      director  \
# 0                         NaN
# 1  Luis Ara, Ignacio Jaunsolo
#
#                                                 cast      country date_added  \
# 0  Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...  South Korea 2019-11-30
# 1                                  Christian Morales          NaN 2019-11-30
#
#    release_year rating  duration  \
# 0        2019.0  TV-14  1 Season
# 1        2019.0   TV-G    67 min
#
#                                            listed_in  \
# 0  International TV Shows, Korean TV Shows, Roman...
# 1                Documentaries, International Movies
#
#                                          description     type    year
# 0  Brought together by meaningful meals in the pa...  TV Show  2019.0
# ...

# %%
# (2)= Perform some operations on Rows
#Get any row using loc

df.loc[1].head(2)
# Out:
# show_id                             81197050.0
# title      Guatemala: Heart of the Mayan World
# Name: 1, dtype: object

# %%
# Drop any or multple rows using drop

df.drop(index=0).head(2)
# Out:
#       show_id                                title  \
# 1  81197050.0  Guatemala: Heart of the Mayan World
# 2  81213894.0                      The Zoya Factor
#
#                      director  \
# 1  Luis Ara, Ignacio Jaunsolo
# 2             Abhishek Sharma
#
#                                                 cast country date_added  \
# 1                                  Christian Morales     NaN 2019-11-30
# 2  Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...   India 2019-11-30
#
#    release_year rating duration                               listed_in  \
# 1        2019.0   TV-G   67 min     Documentaries, International Movies
# 2        2019.0  TV-14  135 min  Comedies, Dramas, International Movies
#
#                                          description   type    year
# 1  From Sierra de las Minas to Esquipulas, explor...  Movie  2019.0
# 2  A goofy copywriter unwittingly convinces the I...  Movie  2019.0

# %%
# Drop any or multple rows using drop

df.drop(index=[0,2]).head(3)
# Out:
#       show_id                                title  \
# 1  81197050.0  Guatemala: Heart of the Mayan World
# 3  81082007.0                            Atlantics
# 4  80213643.0                      Chip and Potato
#
#                      director  \
# 1  Luis Ara, Ignacio Jaunsolo
# 3                   Mati Diop
# 4                         NaN
#
#                                                 cast  \
# 1                                  Christian Morales
# 3  Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# 4  Abigail Oliver, Andrea Libman, Briana Buckmast...
#
#                     country date_added  release_year rating   duration  \
# 1                       NaN 2019-11-30        2019.0   TV-G     67 min
# 3  France, Senegal, Belgium 2019-11-29        2019.0  TV-14    106 min
# 4    Canada, United Kingdom        NaT        2019.0   TV-Y  2 Seasons
#
#                                           listed_in  \
# 1               Documentaries, International Movies
# ...

# %%
# Drop any or multple rows using drop

df.drop(df.index[1:10]).head(2)
# Out:
#        show_id      title      director  \
# 0   81193313.0  Chocolate           NaN
# 10  81172899.0     Payday  Cheta Chukwu
#
#                                                  cast      country date_added  \
# 0   Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...  South Korea 2019-11-30
# 10  Baaj Adebule, Ebiye Victor, Meg Otanwa, Bisola...      Nigeria 2019-11-29
#
#     release_year rating  duration  \
# 0         2019.0  TV-14  1 Season
# 10        2018.0  TV-MA   110 min
#
#                                             listed_in  \
# 0   International TV Shows, Korean TV Shows, Roman...
# 10  Comedies, Independent Movies, International Mo...
#
#                                           description     type    year
# 0   Brought together by meaningful meals in the pa...  TV Show  2019.0
# 10  After an expensive night out, two flatmates ge...    Movie  2019.0

# %%
# (3)= Sorting some values and columns or index

df.sort_index(ascending=False).head(2)
# Out:
#          show_id                 title              director  \
# 5837  70053412.0  To and From New York  Sorin Dan Mihalcescu
# 5836  70157452.0       Dinner for Five                   NaN
#
#                                                    cast        country  \
# 5837  Barbara King, Shaana Diya, John Krisiukenas, Y...  United States
# 5836                                                NaN  United States
#
#      date_added  release_year rating  duration  \
# 5837 2008-01-01        2006.0     NR    81 min
# 5836 2008-02-04        2007.0  TV-MA  1 Season
#
#                                   listed_in  \
# 5837  Dramas, Independent Movies, Thrillers
# 5836           Stand-Up Comedy & Talk Shows
#
#                                             description     type    year
# 5837  While covering a story in New York City, a Sea...    Movie  2008.0
# 5836  In each episode, four celebrities join host Jo...  TV Show  2008.0

# %%
# Sort by columns values

df.sort_values(by='date_added',ascending=False).head(3)
# Out:
#       show_id                                title  \
# 0  81193313.0                            Chocolate
# 2  81213894.0                      The Zoya Factor
# 1  81197050.0  Guatemala: Heart of the Mayan World
#
#                      director  \
# 0                         NaN
# 2             Abhishek Sharma
# 1  Luis Ara, Ignacio Jaunsolo
#
#                                                 cast      country date_added  \
# 0  Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...  South Korea 2019-11-30
# 2  Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...        India 2019-11-30
# 1                                  Christian Morales          NaN 2019-11-30
#
#    release_year rating  duration  \
# 0        2019.0  TV-14  1 Season
# 2        2019.0  TV-14   135 min
# 1        2019.0   TV-G    67 min
#
#                                            listed_in  \
# 0  International TV Shows, Korean TV Shows, Roman...
# 2             Comedies, Dramas, International Movies
# ...

# %%
# Grouping the Values of particular column
# No of Shows per Country

df.groupby('country')['type'].count().head(5)
# Out:
# country
# Argentina                                              38
# Argentina, Brazil, France, Poland, Germany, Denmark     1
# Argentina, Chile                                        1
# Argentina, Chile, Peru                                  1
# Argentina, France                                       1
# Name: type, dtype: int64

# %%
df.groupby(['country','release_year'])['type'].count().head(5)
# Out:
# country    release_year
# Argentina  1985.0          1
#            1998.0          1
#            2006.0          1
#            2007.0          1
#            2015.0          4
# Name: type, dtype: int64

# %% [markdown]
# **How many Movies & TV Shows are in the dataset ?**

# %%
# (5)= Filter Operation on some values and columns or index

df['type'].value_counts()
# Out:
# type
# Movie      3939
# TV Show    1898
# Name: count, dtype: int64

# %%
# Get the Unique with number values 

df['rating'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0       TV-14
# 1        TV-G
# 2       TV-14
# 3       TV-14
# 4        TV-Y
#         ...
# 5833       NR
# 5834    TV-14
# 5835       NR
# 5836    TV-MA
# 5837       NR
# Name: rating, Length: 5838, dtype: object>

# %%
# Get Only particular value from column

df[df['type']=='Movie'].head(2)
# Out:
#       show_id                                title  \
# 1  81197050.0  Guatemala: Heart of the Mayan World
# 2  81213894.0                      The Zoya Factor
#
#                      director  \
# 1  Luis Ara, Ignacio Jaunsolo
# 2             Abhishek Sharma
#
#                                                 cast country date_added  \
# 1                                  Christian Morales     NaN 2019-11-30
# 2  Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...   India 2019-11-30
#
#    release_year rating duration                               listed_in  \
# 1        2019.0   TV-G   67 min     Documentaries, International Movies
# 2        2019.0  TV-14  135 min  Comedies, Dramas, International Movies
#
#                                          description   type    year
# 1  From Sierra de las Minas to Esquipulas, explor...  Movie  2019.0
# 2  A goofy copywriter unwittingly convinces the I...  Movie  2019.0

# %% [markdown]
# **In which year the highest number of the TV Shows & Movies were released ?**

# %%
# Filter Data through multiple conditions

df[(df['type']=='Movie') & (df['release_year']==2015)][['type','release_year']].head(3)
# Out:
#       type  release_year
# 48   Movie        2015.0
# 70   Movie        2015.0
# 104  Movie        2015.0

# %%
# First way to  filter

df[df['country']=='India']['country'].head(2)
# Out:
# 2     India
# 24    India
# Name: country, dtype: object

# %%
# Second way to  filter

df[df['country'].str.contains('India',na=False)]['country'].head(2)
# Out:
# 2     India
# 24    India
# Name: country, dtype: object

# %%
df.shape
# Out:
# (5838, 13)

# %%
df=df.dropna(subset=['rating','country'])

# %%
# Its ruturning Blank DataFrame, Which means no rows match both conditions.

df[(df['country']=='India') & (df['rating'].isin([['TV-MA','TV-14']]))][['country','rating']]
# Out:
# Empty DataFrame
# Columns: [country, rating]
# Index: []

# %% [markdown]
# **Show only the Rating of all TV Shows Type that were released in India only.**

# %%
#Check for case sensitivity or Extra spaces

df['country']=df['country'].str.strip().str.lower()
df['rating']=df['rating'].str.strip().str.upper()
df[(df['country']=='india') & (df['rating'].isin(['TV-MA','TV-14']))][['country','rating','type']].head(5)
# Out:
#     country rating   type
# 2     india  TV-14  Movie
# 24    india  TV-14  Movie
# 34    india  TV-MA  Movie
# 69    india  TV-14  Movie
# 110   india  TV-MA  Movie

# %%
# Get the lengh of any column and each words

df['title'].str.len().head(5)
# Out:
# 0     9
# 2    15
# 3     9
# 4    15
# 5    12
# Name: title, dtype: int64

# %%
# Convert any Charecter

df['title'].str.lower().head(2)
# Out:
# 0          chocolate
# 2    the zoya factor
# Name: title, dtype: object

# %%
# Display rows contains more than one Values

df['multi_contries']=df['country'].str.contains(',',na=False)

#That showing , separeted 

df[df['multi_contries']].head(2)
# Out:
#       show_id            title   director  \
# 3  81082007.0        Atlantics  Mati Diop
# 4  80213643.0  Chip and Potato        NaN
#
#                                                 cast  \
# 3  Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# 4  Abigail Oliver, Andrea Libman, Briana Buckmast...
#
#                     country date_added  release_year rating   duration  \
# 3  france, senegal, belgium 2019-11-29        2019.0  TV-14    106 min
# 4    canada, united kingdom        NaT        2019.0   TV-Y  2 Seasons
#
#                                           listed_in  \
# 3  Dramas, Independent Movies, International Movies
# 4                                          Kids' TV
#
#                                          description     type    year  \
# 3  Arranged to marry a rich man, young Ada is cru...    Movie  2019.0
# 4  Lovable pug Chip starts kindergarten, makes ne...  TV Show     NaN
#
#    multi_contries
# 3            True
# 4            True

# %%
df[df['multi_contries']]['country'].dropna().str.split(',').explode().value_counts()
# Out:
# country
#  united states     280
# united states      234
# united kingdom     120
#  france            115
#  united kingdom    103
#                   ...
# peru                 1
# croatia              1
#  montenegro          1
#  ukraine             1
#  azerbaijan          1
# Name: count, Length: 162, dtype: int64

# %%
df['multi_contries'].sum()
# Out:
# 847

# %% [markdown]
# **Is there any Null Value present in any column ?**

# %%
# (6)= Handling missing Data 

df.isnull().sum()
# Out:
# show_id              0
# title                0
# director          1616
# cast               476
# country              0
# date_added         611
# release_year         0
# rating               0
# duration             0
# listed_in            0
# description          0
# type                 0
# year               611
# multi_contries       0
# dtype: int64

# %% [markdown]
# **Convert how many percent of null value contribute into the columns**

# %%
round(df.isnull().sum()/df.shape[0]*100,2)
# Out:
# show_id            0.00
# title              0.00
# director          29.90
# cast               8.81
# country            0.00
# date_added        11.31
# release_year       0.00
# rating             0.00
# duration           0.00
# listed_in          0.00
# description        0.00
# type               0.00
# year              11.31
# multi_contries     0.00
# dtype: float64

# %%
# Count the rows of NAN values

nan=df.isna().any().sum()
nan
# Out:
# 4

# %%
# Display NAN values 

df[df.isna().any(axis=1)].head(2)
# Out:
#       show_id            title director  \
# 0  81193313.0        Chocolate      NaN
# 4  80213643.0  Chip and Potato      NaN
#
#                                                 cast                 country  \
# 0  Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...             south korea
# 4  Abigail Oliver, Andrea Libman, Briana Buckmast...  canada, united kingdom
#
#   date_added  release_year rating   duration  \
# 0 2019-11-30        2019.0  TV-14   1 Season
# 4        NaT        2019.0   TV-Y  2 Seasons
#
#                                            listed_in  \
# 0  International TV Shows, Korean TV Shows, Roman...
# 4                                           Kids' TV
#
#                                          description     type    year  \
# 0  Brought together by meaningful meals in the pa...  TV Show  2019.0
# 4  Lovable pug Chip starts kindergarten, makes ne...  TV Show     NaN
#
#    multi_contries
# 0           False
# 4            True

# %% [markdown]
# **How to get only those coulmns which contains NAN values?**

# %%
# Get only NAN values column

df.loc[:,df.isna().any()].head(3)
# Out:
#           director                                               cast  \
# 0              NaN  Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...
# 2  Abhishek Sharma  Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3        Mati Diop  Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
#
#   date_added    year
# 0 2019-11-30  2019.0
# 2 2019-11-30  2019.0
# 3 2019-11-29  2019.0

# %%
# Remove rows with NAN
# Remove columns with NAN

df.dropna(axis=0)
df.dropna(axis=1)
# Out:
#          show_id                        title                   country  \
# 0     81193313.0                    Chocolate               south korea
# 2     81213894.0              The Zoya Factor                     india
# 3     81082007.0                    Atlantics  france, senegal, belgium
# 4     80213643.0              Chip and Potato    canada, united kingdom
# 5     81172754.0                 Crazy people                   nigeria
# ...          ...                          ...                       ...
# 5833  70141644.0  Mad Ron's Prevues from Hell             united states
# 5834  70127998.0                     Splatter             united states
# 5835  70084180.0      Just Another Love Story                   denmark
# 5836  70157452.0              Dinner for Five             united states
# 5837  70053412.0         To and From New York             united states
#
#       release_year rating   duration  \
# 0           2019.0  TV-14   1 Season
# ...

# %%
# Remove all  NAN with Oringinal DataFrame

df.dropna(inplace=True)
df.shape
# Out:
# (3447, 14)

# %%
# Drop the rows where director is missing

df.dropna(subset=['director']).head(3)
# Out:
#       show_id            title         director  \
# 2  81213894.0  The Zoya Factor  Abhishek Sharma
# 3  81082007.0        Atlantics        Mati Diop
# 5  81172754.0     Crazy people     Moses Inwang
#
#                                                 cast  \
# 2  Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3  Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# 5  Ramsey Nouah, Chigul, Sola Sobowale, Ireti Doy...
#
#                     country date_added  release_year rating duration  \
# 2                     india 2019-11-30        2019.0  TV-14  135 min
# 3  france, senegal, belgium 2019-11-29        2019.0  TV-14  106 min
# 5                   nigeria 2019-11-29        2018.0  TV-14  107 min
#
#                                           listed_in  \
# 2            Comedies, Dramas, International Movies
# 3  Dramas, Independent Movies, International Movies
# 5         Comedies, International Movies, Thrillers
#
# ...

# %%
# Now fill NAN  with a specified values
df.fillna('Unknown').head(2)
# Out:
#       show_id            title         director  \
# 2  81213894.0  The Zoya Factor  Abhishek Sharma
# 3  81082007.0        Atlantics        Mati Diop
#
#                                                 cast  \
# 2  Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3  Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
#
#                     country date_added  release_year rating duration  \
# 2                     india 2019-11-30        2019.0  TV-14  135 min
# 3  france, senegal, belgium 2019-11-29        2019.0  TV-14  106 min
#
#                                           listed_in  \
# 2            Comedies, Dramas, International Movies
# 3  Dramas, Independent Movies, International Movies
#
#                                          description   type    year  \
# 2  A goofy copywriter unwittingly convinces the I...  Movie  2019.0
# 3  Arranged to marry a rich man, young Ada is cru...  Movie  2019.0
#
#    multi_contries
# 2           False
# 3            True

# %%
# Replace NAN values of a columns with specific value

df['country'].replace(np.nan,'United States')
# Out:
# 2                          india
# 3       france, senegal, belgium
# 5                        nigeria
# 6                         france
# 7                   south africa
#                   ...
# 5832       spain, mexico, france
# 5833               united states
# 5834               united states
# 5835                     denmark
# 5837               united states
# Name: country, Length: 3447, dtype: object

# %%
# Out:
#             show_id                     date_added  release_year         year
# count  3.447000e+03                           3447   3447.000000  3447.000000
# mean   7.599440e+07  2018-05-23 15:06:06.579634432   2012.572962  2017.887728
# min    2.698800e+05            2008-01-01 00:00:00   1942.000000  2008.000000
# 25%    7.030419e+07            2017-09-18 12:00:00   2012.000000  2017.000000
# 50%    8.015418e+07            2018-08-02 00:00:00   2016.000000  2018.000000
# 75%    8.023963e+07            2019-04-01 00:00:00   2017.000000  2019.000000
# max    8.122720e+07            2019-11-30 00:00:00   2019.000000  2019.000000
# std    1.180951e+07                            NaN      9.114564     1.174001

# %%
# Create 2X2 subsplots

fig,axs=plt.subplots(2,2)

# %%
# Type distribution Pie chart

df['type'].value_counts().plot(kind='pie',autopct='%1.1f%%',color=['grey','lightpink'],title='ContentType')
plt.show()

# %%
# Show Top 5 countries 

df['country'].dropna().str.split(',').value_counts().head(5).plot(kind='barh',color='skyblue',title='Top 5 Countries')
plt.show()

# %%
# Show Top 5 ratings

df['rating'].value_counts().head(5).plot(kind='bar',color='lightgreen',title='Top 5 ratings')
plt.show()

# %%
# Release over Year 

df['release_year'].value_counts().sort_index().plot(marker='o',color='coral')
plt.show()

# %%
# Here is your Dashboard

fig,axs=plt.subplots(2,2,figsize=(15,8))
df['type'].value_counts().plot(kind='pie',ax=axs[0,0],autopct='%1.1f%%',color=['grey','lightpink'],title='ContentType')
axs[0,0].set_ylabel('')

df['country'].dropna().str.split(',').value_counts().head(5).plot(kind='barh',ax=axs[0,1],color='skyblue',title='Top 5 Countries')
axs[0,1].set_ylabel('')
axs[0,1].invert_yaxis()


df['rating'].value_counts().head(5).plot(kind='bar',ax=axs[1,0],color='lightgreen',title='Top 5 ratings')
axs[1,0].set_xlabel('')

df['release_year'].value_counts().sort_index().plot(marker='o',ax=axs[1,1],color='coral')
axs[1,1].set_title('Release Over Years')

fig.suptitle('Deshboard-NetFlix',fontsize=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# **(The commands that we used in this project :)**
#
#
#
# .head() - It shows the first N rows in the data (by default, N=5).
# .tail () - It shows the last N rows in the data (by default, N=5).
# .shape - It shows the total no. of rows and no. of columns of the dataframe.
# .size - To show No. of total values(elements) in the dataset.
# .columns - To show each Column Name.
# .dtypes - To show the data-type of each column.
# .info() - To show indexes, columns, data-types of each column, memory at once.
# .value_counts - In a column, it shows all the unique values with their count. It can be applied on a single column only.
# .unique() - It shows the all unique values of the series.
# .nunique() - It shows the total no. of unique values in the series.
# .duplicated( ) - To check row wise and detect the Duplicate rows.
# .isnull( ) - To show where Null value is present.
# .dropna( ) - It drops the rows that contains all missing values.
# .isin( ) - To show all records including particular elements.
# .str.contains( ) - To get all records that contains a given string.
# .str.split( ) - It splits a column's string into different columns.
# .to_datetime( ) - Converts the data-type of Date-Time Column into datetime[ns] datatype.
# .dt.year.value_counts( ) - It counts the occurrence of all individual years in Time column.
# .groupby( ) - Groupby is used to split the data into groups based on some criteria.
# .sns.countplot(df['Col_name']) - To show the count of all unique values of any column in the form of bar graph.
# .max( ), min( ) - It shows the maximum/minimum value of the series.
# .mean( ) - It shows the mean value of the series.
